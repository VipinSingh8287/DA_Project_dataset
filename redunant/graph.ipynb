# %% [markdown]
# Following code blocks imports the neccessary module required
# - Pandas: It provides the *DataFrame* object which stores the input read from csv file
# - Matplotlib.Pyplot and Seaborn: It provides the method to plot the graphs

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# df is being read from csv file to pandas dataframe

# %%
df = pd.read_csv("./data.csv")

# %% [markdown]
# Here the unique states are pulled from State Column

# %%
states = df['State'].unique()

# %% [markdown]
# Here the Date column is converted to *datetime* format through pandas in built method.

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %%
df.iloc[:,3:] = df.iloc[:,3:]/100000
# Out:
#            Date       Source                        State  Potential Capacity  \
# 0    2023-11-01        Hydro  Andaman and Nicobar Islands             1.45320
# 1    2023-11-01         Wind  Andaman and Nicobar Islands             6.95509
# 2    2023-11-01        Solar  Andaman and Nicobar Islands             7.48990
# 3    2023-11-01    Bio Power  Andaman and Nicobar Islands             0.25094
# 4    2023-11-01  Small-Hydro  Andaman and Nicobar Islands             0.21130
# ...         ...          ...                          ...                 ...
# 4555 2020-11-01        Hydro                  West Bengal             1.45320
# 4556 2020-11-01         Wind                  West Bengal             6.95509
# 4557 2020-11-01        Solar                  West Bengal             7.48990
# 4558 2020-11-01    Bio Power                  West Bengal             0.25094
# 4559 2020-11-01  Small-Hydro                  West Bengal             0.21130
#
#       Installed Capacity
# 0               0.468802
# 1               0.445637
# 2               0.723117
# 3               0.108364
# 4               0.049867
# ...                  ...
# 4555            0.457322
# 4556            0.384336
# 4557            0.369105
# 4558            0.103146
# 4559            0.047405
#
# [4560 rows x 5 columns]

# %% [markdown]
# Following code blocks does all the hardwork. It plot a lineplot for each state for Date vs Capacity with hue as Source. It also saves the code after it generates the plot.
# close method is very neccessary. It deletes the plot hogged memory after saving it to hard drive.

# %%
# from sklearn.preprocessing import StandardScaler
# sc = StandardScaler()
# sc.fit(df.iloc[:,3:])
# df.iloc[:,3:] = sc.transform(df.iloc[:,3:])

for state in states:
    df_state = df[df['State'] == state]
    plt.figure(figsize=(20,8))
    sns.lineplot(data=df_state,x='Date',y='Installed Capacity',hue='Source',palette="tab10",marker="o")
    sns.lineplot(data=df_state,x='Date',y='Potential Capacity',hue='Source',palette="tab10",linestyle="--",marker="x")
    plt.title(f"Potential vs Installed Capacity over Time in {state}")
    plt.xlabel("Date")
    plt.ylabel("Capacity")
    plt.legend(loc="best")
    # plt.savefig(f"./graphs/LinePlots/Scaled/{state}Graph.jpeg")
    plt.show()
    plt.close()
